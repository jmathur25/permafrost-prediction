# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import pandas as pd

sys.path.append("..")
from methods.utils import compute_stats
from methods.soil_models import alt_to_surface_deformation, compute_alt_f_deformation
# Out:
# Using default ISCE Path: /usr/lib/python3.8/dist-packages/isce

# %%
sub_pred = np.load("../../../subsidence.npy")
alt_pred = np.load("../../../alt_preds.npy")
alt_gt = np.load("../../../alt_gt.npy")
df_alt_gt = pd.read_csv("../../../df_alt_gt.csv")

# %%
plt.scatter(alt_pred, alt_gt)
plt.ylabel("ALT ground-truth")
plt.xlabel("ALT predicted")
# Out:
# Text(0.5, 0, 'ALT predicted')
